# %%
import numpy as np
import matplotlib.pyplot as pp
import pandas as pd
import seaborn

# %%
# %matplotlib inline

# %%
import zipfile
zipfile.ZipFile('names.zip').extractall('.')

# %%
import os
os.listdir('names')
# Out:
# ['NationalReadMe.pdf',
#  'yob1880.txt',
#  'yob1881.txt',
#  'yob1882.txt',
#  'yob1883.txt',
#  'yob1884.txt',
#  'yob1885.txt',
#  'yob1886.txt',
#  'yob1887.txt',
#  'yob1888.txt',
#  'yob1889.txt',
#  'yob1890.txt',
#  'yob1891.txt',
#  'yob1892.txt',
#  'yob1893.txt',
#  'yob1894.txt',
#  'yob1895.txt',
#  'yob1896.txt',
#  'yob1897.txt',
#  'yob1898.txt',
#  'yob1899.txt',
#  'yob1900.txt',
#  'yob1901.txt',
#  'yob1902.txt',
#  'yob1903.txt',
#  'yob1904.txt',
#  'yob1905.txt',
#  'yob1906.txt',
#  'yob1907.txt',
#  'yob1908.txt',
#  'yob1909.txt',
#  'yob1910.txt',
#  'yob1911.txt',
#  'yob1912.txt',
#  'yob1913.txt',
#  'yob1914.txt',
#  'yob1915.txt',
#  'yob1916.txt',
#  'yob1917.txt',
#  'yob1918.txt',
#  'yob1919.txt',
#  'yob1920.txt',
#  'yob1921.txt',
#  'yob1922.txt',
#  'yob1923.txt',
#  'yob1924.txt',
#  'yob1925.txt',
#  'yob1926.txt',
#  'yob1927.txt',
#  'yob1928.txt',
#  'yob1929.txt',
#  'yob1930.txt',
#  'yob1931.txt',
#  'yob1932.txt',
#  'yob1933.txt',
#  'yob1934.txt',
#  'yob1935.txt',
#  'yob1936.txt',
#  'yob1937.txt',
#  'yob1938.txt',
#  'yob1939.txt',
#  'yob1940.txt',
#  'yob1941.txt',
#  'yob1942.txt',
#  'yob1943.txt',
#  'yob1944.txt',
#  'yob1945.txt',
#  'yob1946.txt',
#  'yob1947.txt',
#  'yob1948.txt',
#  'yob1949.txt',
#  'yob1950.txt',
#  'yob1951.txt',
#  'yob1952.txt',
#  'yob1953.txt',
#  'yob1954.txt',
#  'yob1955.txt',
#  'yob1956.txt',
#  'yob1957.txt',
#  'yob1958.txt',
#  'yob1959.txt',
#  'yob1960.txt',
#  'yob1961.txt',
#  'yob1962.txt',
#  'yob1963.txt',
#  'yob1964.txt',
#  'yob1965.txt',
#  'yob1966.txt',
#  'yob1967.txt',
#  'yob1968.txt',
#  'yob1969.txt',
#  'yob1970.txt',
#  'yob1971.txt',
#  'yob1972.txt',
#  'yob1973.txt',
#  'yob1974.txt',
#  'yob1975.txt',
#  'yob1976.txt',
#  'yob1977.txt',
#  'yob1978.txt',
#  'yob1979.txt',
#  'yob1980.txt',
#  'yob1981.txt',
#  'yob1982.txt',
#  'yob1983.txt',
#  'yob1984.txt',
#  'yob1985.txt',
#  'yob1986.txt',
#  'yob1987.txt',
#  'yob1988.txt',
#  'yob1989.txt',
#  'yob1990.txt',
#  'yob1991.txt',
#  'yob1992.txt',
#  'yob1993.txt',
#  'yob1994.txt',
#  'yob1995.txt',
#  'yob1996.txt',
#  'yob1997.txt',
#  'yob1998.txt',
#  'yob1999.txt',
#  'yob2000.txt',
#  'yob2001.txt',
#  'yob2002.txt',
#  'yob2003.txt',
#  'yob2004.txt',
#  'yob2005.txt',
#  'yob2006.txt',
#  'yob2007.txt',
#  'yob2008.txt',
#  'yob2009.txt',
#  'yob2010.txt',
#  'yob2011.txt',
#  'yob2012.txt',
#  'yob2013.txt',
#  'yob2014.txt']

# %%
open('names/yob2011.txt','r').readlines()[:10]
# Out:
# ['Sophia,F,21816\n',
#  'Isabella,F,19870\n',
#  'Emma,F,18777\n',
#  'Olivia,F,17294\n',
#  'Ava,F,15480\n',
#  'Emily,F,14236\n',
#  'Abigail,F,13229\n',
#  'Madison,F,12360\n',
#  'Mia,F,11512\n',
#  'Chloe,F,10970\n']

# %%
names2011 = pd.read_csv('names/yob2011.txt')

# %%
names2011.head()
# Out:
#      Sophia  F  21816
# 0  Isabella  F  19870
# 1      Emma  F  18777
# 2    Olivia  F  17294
# 3       Ava  F  15480
# 4     Emily  F  14236

# %%
names2011 = pd.read_csv('names/yob2011.txt',names=['name','sex','number'])

# %%
names2011.head()
# Out:
#        name sex  number
# 0    Sophia   F   21816
# 1  Isabella   F   19870
# 2      Emma   F   18777
# 3    Olivia   F   17294
# 4       Ava   F   15480

# %%
names_all = []

for year in range(1880,2014+1):
    names_all.append(pd.read_csv('names/yob{}.txt'.format(year),names=['name','sex','number']))
    names_all[-1]['year'] = year

allyears = pd.concat(names_all)

# %%
allyears.head()
# Out:
#         name sex  number  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880

# %%
allyears.tail()
# Out:
#           name sex  number  year
# 33039   Zykeem   M       5  2014
# 33040   Zymeer   M       5  2014
# 33041  Zymiere   M       5  2014
# 33042    Zyran   M       5  2014
# 33043    Zyrin   M       5  2014

# %%
allyears_indexed = allyears.set_index(['sex','name','year']).sort_index()

# %%
allyears_indexed
# Out:
#                     number
# sex name      year
# F   Aabha     2011       7
#               2012       5
#               2014       9
#     Aabriella 2008       5
#               2014       5
# ...                    ...
# M   Zytavious 2009       7
#               2010       6
#     Zyvion    2009       5
#     Zyyon     2014       6
#     Zzyzx     2010       5
#
# [1825433 rows x 1 columns]

# %%
allyears_indexed.loc['F','Mary']
# Out:
#       number
# year
# 1880    7065
# 1881    6919
# 1882    8148
# 1883    8012
# 1884    9217
# ...      ...
# 2010    2862
# 2011    2701
# 2012    2565
# 2013    2632
# 2014    2611
#
# [135 rows x 1 columns]

# %%
def plotname(sex,name):
    data = allyears_indexed.loc[sex,name]
    
    pp.plot(data.index,data.values)

# %%
pp.figure(figsize=(12,2.5))

names = ['Michael','John','David','Martin']

for name in names:
    plotname('M',name)

pp.legend(names)

# %%
pp.figure(figsize=(12,2.5))

names = ['Emily','Anna','Claire','Elizabeth']

for name in names:
    plotname('F',name)

pp.legend(names)

# %%
pp.figure(figsize=(12,2.5))

names = ['Chiara','Claire','Clare','Clara','Ciara']

for name in names:
    plotname('F',name)

pp.legend(names)

# %%
allyears_indexed.loc['F'].loc[names].head()
# Out:
#              number
# name   year
# Chiara 1959       9
#        1960       5
#        1962       8
#        1963       8
#        1964      12

# %%
allyears_indexed.loc['F'].loc[names].unstack(level=0).head()
# Out:
#      number
# name Chiara Claire Clare   Clara Ciara
# year
# 1880    NaN   21.0  15.0  1226.0   NaN
# 1881    NaN   23.0  20.0  1242.0   NaN
# 1882    NaN   30.0  21.0  1490.0   NaN
# 1883    NaN   38.0  22.0  1548.0   NaN
# 1884    NaN   33.0  38.0  1852.0   NaN

# %%
allyears_indexed.loc['F'].loc[names].unstack(level=0).fillna(0).head()
# Out:
#      number
# name Chiara Claire Clare   Clara Ciara
# year
# 1880    0.0   21.0  15.0  1226.0   0.0
# 1881    0.0   23.0  20.0  1242.0   0.0
# 1882    0.0   30.0  21.0  1490.0   0.0
# 1883    0.0   38.0  22.0  1548.0   0.0
# 1884    0.0   33.0  38.0  1852.0   0.0

# %%
variants = allyears_indexed.loc['F'].loc[names].unstack(level=0).fillna(0)

# %%
pp.figure(figsize=(12,2.5))

pp.stackplot(variants.index,variants.values.T)
# Out:
# [<matplotlib.collections.PolyCollection at 0x1e78022a620>,
#  <matplotlib.collections.PolyCollection at 0x1e78022a980>,
#  <matplotlib.collections.PolyCollection at 0x1e78022ace0>,
#  <matplotlib.collections.PolyCollection at 0x1e78022b040>,
#  <matplotlib.collections.PolyCollection at 0x1e78022b3a0>]

# %%
pp.figure(figsize=(12,2.5))

palette = seaborn.color_palette()
pp.stackplot(variants.index,variants.values.T,colors=palette)

for i,name in enumerate(names):
    pp.text(1882,5000 + 800*i,name,color=palette[i])

# %%
allyears_indexed.loc['M',:,2008].sort_values('number',ascending=False).unstack(level=0).head()
# Out:
#         name
# number  Jacob      22568
#         Michael    20590
#         Ethan      20196
#         Joshua     19186
#         Daniel     18985
# dtype: int64

# %%
pop2008 = allyears_indexed.loc['M',:,2008].sort_values('number',ascending=False).head()

# %%
pop2008.reset_index().drop(['number'],axis=1).head()
# Out:
#       name
# 0    Jacob
# 1  Michael
# 2    Ethan
# 3   Joshua
# 4   Daniel

# %%
def topten(sex,year):
    simple = allyears_indexed.loc[sex,:,year].sort_values('number',ascending=False).reset_index()
    simple = simple.drop(['number'],axis=1).head(10)
    
    simple.columns = [year]
    simple.index = simple.index + 1
    
    return simple

# %%
topten('M',2009)
# Out:
#            2009
# 1         Jacob
# 2         Ethan
# 3       Michael
# 4     Alexander
# 5       William
# 6        Joshua
# 7        Daniel
# 8        Jayden
# 9          Noah
# 10  Christopher

# %%
def toptens(sex,year0,year1):
    years = [topten(sex,year) for year in range(year0,year1+1)]
    
    return years[0].join(years[1:])

# %%
toptens('M',2000,2010)
# Out:
#            2000         2001         2002         2003         2004  \
# 1         Jacob        Jacob        Jacob        Jacob        Jacob
# 2       Michael      Michael      Michael      Michael      Michael
# 3       Matthew      Matthew       Joshua       Joshua       Joshua
# 4        Joshua       Joshua      Matthew      Matthew      Matthew
# 5   Christopher  Christopher        Ethan       Andrew        Ethan
# 6      Nicholas     Nicholas       Andrew        Ethan       Andrew
# 7        Andrew       Andrew       Joseph       Joseph       Daniel
# 8        Joseph       Joseph  Christopher       Daniel      William
# 9        Daniel       Daniel     Nicholas  Christopher       Joseph
# 10        Tyler      William       Daniel      Anthony  Christopher
#
#            2005         2006         2007         2008         2009       2010
# 1         Jacob        Jacob        Jacob        Jacob        Jacob      Jacob
# 2       Michael      Michael      Michael      Michael        Ethan      Ethan
# 3        Joshua       Joshua        Ethan        Ethan      Michael    Michael
# 4       Matthew        Ethan       Joshua       Joshua    Alexander     Jayden
# 5         Ethan      Matthew       Daniel       Daniel      William    William
# 6        Andrew       Daniel  Christopher    Alexander       Joshua  Alexander
# 7        Daniel       Andrew      Anthony      William       Daniel       Noah
# 8       Anthony  Christopher      William      Anthony       Jayden     Daniel
# 9        Joseph      Anthony      Matthew  Christopher         Noah      Aiden
# 10  Christopher      William       Andrew      Matthew  Christopher    Anthony

# %%
toptens('F',1985,1995)
# Out:
#          1985       1986       1987       1988       1989       1990  \
# 1     Jessica    Jessica    Jessica    Jessica    Jessica    Jessica
# 2      Ashley     Ashley     Ashley     Ashley     Ashley     Ashley
# 3    Jennifer     Amanda     Amanda     Amanda   Brittany   Brittany
# 4      Amanda   Jennifer   Jennifer      Sarah     Amanda     Amanda
# 5       Sarah      Sarah      Sarah   Jennifer      Sarah   Samantha
# 6   Stephanie  Stephanie  Stephanie   Brittany   Samantha      Sarah
# 7      Nicole     Nicole   Brittany  Stephanie   Jennifer  Stephanie
# 8     Heather   Brittany     Nicole   Samantha  Stephanie   Jennifer
# 9   Elizabeth    Heather    Heather     Nicole     Lauren  Elizabeth
# 10      Megan  Elizabeth  Elizabeth  Elizabeth  Elizabeth     Lauren
#
#          1991       1992       1993       1994       1995
# 1      Ashley     Ashley    Jessica    Jessica    Jessica
# 2     Jessica    Jessica     Ashley     Ashley     Ashley
# 3    Brittany     Amanda      Sarah      Emily      Emily
# 4      Amanda   Brittany   Samantha   Samantha   Samantha
# 5    Samantha      Sarah      Emily      Sarah      Sarah
# 6       Sarah   Samantha   Brittany     Taylor     Taylor
# 7   Stephanie      Emily     Taylor   Brittany     Hannah
# 8    Jennifer  Stephanie     Amanda     Amanda   Brittany
# 9   Elizabeth  Elizabeth  Elizabeth  Elizabeth     Amanda
# 10      Emily      Megan  Stephanie      Megan  Elizabeth

# %%
toptens('F',1985,1995).stack().head()
# Out:
# 1  1985    Jessica
#    1986    Jessica
#    1987    Jessica
#    1988    Jessica
#    1989    Jessica
# dtype: object

# %%
toptens('F',1985,1995).stack().value_counts()
# Out:
# Jessica      11
# Ashley       11
# Amanda       11
# Sarah        11
# Elizabeth    11
# Brittany     10
# Stephanie     9
# Samantha      8
# Jennifer      7
# Emily         5
# Nicole        4
# Taylor        3
# Heather       3
# Megan         3
# Lauren        2
# Hannah        1
# dtype: int64

# %%
popular = toptens('F',1985,1995).stack().value_counts().index[:6]

# %%
pp.figure(figsize=(12,2.5))

for name in popular:
    plotname('F',name)
    
pp.legend(popular)

# %%
allyears.head()
# Out:
#         name sex  number  year
# 0       Mary   F    7065  1880
# 1       Anna   F    2604  1880
# 2       Emma   F    2003  1880
# 3  Elizabeth   F    1939  1880
# 4     Minnie   F    1746  1880

# %%
allyears1=allyears.drop('year', axis=1)
totals_bysex=allyears1.groupby(['name', 'sex']).sum('number').unstack('sex')
totals_bysex.columns = totals_bysex.columns.droplevel()

# %%
totals_bysex.head()
# Out:
# sex           F      M
# name
# Aaban       NaN   72.0
# Aabha      21.0    NaN
# Aabid       NaN    5.0
# Aabriella  10.0    NaN
# Aadam       NaN  196.0

# %%
totals_both=totals_bysex.sum(axis=1)

# %%
totals_both.head()
# Out:
# name
# Aaban         72.0
# Aabha         21.0
# Aabid          5.0
# Aabriella     10.0
# Aadam        196.0
# dtype: float64

# %%
ratio = totals_bysex['F'] / totals_bysex['M']

# %%
ratio.head()
# Out:
# name
# Aaban       NaN
# Aabha       NaN
# Aabid       NaN
# Aabriella   NaN
# Aadam       NaN
# dtype: float64

# %%
ratio_elements=ratio[(ratio > 0.25) & (ratio < 4)]
ratio_elements
# Out:
# name
# Aalijah    0.690323
# Aamari     0.761364
# Aaren      0.393305
# Aareon     0.303030
# Aarian     0.526316
#              ...
# Zyaire     0.274634
# Zyan       0.369661
# Zyian      1.400000
# Zyon       0.256937
# Zyree      0.313725
# Length: 3050, dtype: float64

# %%
totals_both.head()
# Out:
# name
# Aaban         72.0
# Aabha         21.0
# Aabid          5.0
# Aabriella     10.0
# Aadam        196.0
# dtype: float64

# %%
filtered_elements = [(element, index) for index, (element, ratio_value) in enumerate(zip(totals_both, ratio)) if 0.25 < ratio_value < 4]

# %%
totals_both = totals_both.loc[(ratio > 0.25) & (ratio < 4)]

# %%
totals_both = totals_both.sort_values(ascending=False)

# %%
totals_both.head(10)
# Out:
# name
# Willie    593888.0
# Jordan    479434.0
# Taylor    416096.0
# Leslie    376587.0
# Jamie     350262.0
# Angel     301425.0
# Lee       291691.0
# Jessie    274931.0
# Marion    259549.0
# Dana      243517.0
# dtype: float64

# %%
allyears_indexed
# Out:
#                     number
# sex name      year
# F   Aabha     2011       7
#               2012       5
#               2014       9
#     Aabriella 2008       5
#               2014       5
# ...                    ...
# M   Zytavious 2009       7
#               2010       6
#     Zyvion    2009       5
#     Zyyon     2014       6
#     Zzyzx     2010       5
#
# [1825433 rows x 1 columns]

# %%
names = totals_both.index[:10]
fig, axs = pp.subplots(figsize=(10, 10))

for i in range(10):
    name = names[i]
    ax = pp.subplot(5, 2, i+1)

    plotname('M', name)
    plotname('F', name)

    pp.legend([(name + ' M'), (name + ' F')], loc='upper left')
    pp.tight_layout()
# Out:
# C:\Users\Rogelio\AppData\Local\Temp\ipykernel_19460\1349846770.py:6: MatplotlibDeprecationWarning: Auto-removal of overlapping axes is deprecated since 3.6 and will be removed two minor releases later; explicitly call ax.remove() as needed.
#   ax = pp.subplot(5, 2, i+1)
